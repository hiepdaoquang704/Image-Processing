# %%
import cv2 as cv 
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv.imread('D:\imageprocessing\messi.jpg',1)
print(img.shape)
img=cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img)
# Out:
# (639, 959, 3)

# %%
mask=np.zeros(img.shape[:2],np.uint8)
print(img.shape[:2])
# Out:
# (639, 959)

# %%
bgdModel=np.zeros((1,65),np.float64)
fgdModel=np.zeros((1,65),np.float64)

# %%
rect = (100,50,500,600)
cv.grabCut(img,mask,rect,bgdModel,fgdModel,10,cv.GC_INIT_WITH_RECT)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img1 = img*mask2[:,:,np.newaxis]
plt.imshow(img1),plt.colorbar(),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x2240d22a910>,
#  <matplotlib.colorbar.Colorbar at 0x2240d2527f0>,
#  None)
